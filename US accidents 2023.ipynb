# %% [markdown]
# # US Accidents Exploratory Data Analysis
#
# TODO - talk about EDA
#
# TODO - talk about the dataset (source, what it contains, how it will be useful)
#   - Kaggle
#   - informaiton about accidents
#   - can use useful to prevent accidents
#   - mention that this does not contain data about New York

# %%
import pandas as pd

# %%
data_filename = '/Users/adityakapoor/Downloads/US_Accidents_March23.csv'

# %% [markdown]
# ## Data Preparation and Cleaning
#
# 1. Load the file using Pandas
# 2. Look at some information about the data & the columns
# 3. Fix any missing or incorrect values

# %%
df = pd.read_csv(data_filename)

# %%
df
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 13

# %% [markdown]
# ## Percentage of missing values per column

# %%
missing_percentages = df.isna().sum().sort_values(ascending=False) / len(df)
missing_percentages
# Out:
# End_Lat                  4.402935e-01
# End_Lng                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature(F)           2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Nautical_Twilight        3.007869e-03
# Civil_Twilight           3.007869e-03
# Sunrise_Sunset           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# Traffic_Signal           0.000000e+00
# Roundabout               0.000000e+00
# Station                  0.000000e+00
# ...

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages != 0
# Out:
# End_Lat                   True
# End_Lng                   True
# Precipitation(in)         True
# Wind_Chill(F)             True
# Wind_Speed(mph)           True
# Visibility(mi)            True
# Wind_Direction            True
# Humidity(%)               True
# Weather_Condition         True
# Temperature(F)            True
# Pressure(in)              True
# Weather_Timestamp         True
# Nautical_Twilight         True
# Civil_Twilight            True
# Sunrise_Sunset            True
# Astronomical_Twilight     True
# Airport_Code              True
# Street                    True
# Timezone                  True
# Zipcode                   True
# City                      True
# Description               True
# Traffic_Signal           False
# Roundabout               False
# Station                  False
# Stop                     False
# Traffic_Calming          False
# Country                  False
# Turning_Loop             False
# No_Exit                  False
# ...

# %% [markdown]
# ### now it will just give us the value of missing value only rather then true of false

# %%
missing_percentages[missing_percentages != 0]
# Out:
# End_Lat                  4.402935e-01
# End_Lng                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature(F)           2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Nautical_Twilight        3.007869e-03
# Civil_Twilight           3.007869e-03
# Sunrise_Sunset           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# dtype: float64

# %%
missing_percentages[missing_percentages != 0].plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# #### Remove columns that you don't want to use.

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# Columns we'll analyze:
#
# 1. City
# 2. Start Time
# 3. Start Lat, Start Lng
# 4. Temperature
# 5. Weather Condition

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# # city

# %%
df.City
# Out:
# 0                Dayton
# 1          Reynoldsburg
# 2          Williamsburg
# 3                Dayton
# 4                Dayton
#                ...
# 7728389       Riverside
# 7728390       San Diego
# 7728391          Orange
# 7728392     Culver City
# 7728393        Highland
# Name: City, Length: 7728394, dtype: object

# %%
cities = df.City.unique()
len(cities)
# Out:
# 13679

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# City
# Miami                           186917
# Houston                         169609
# Los Angeles                     156491
# Charlotte                       138652
# Dallas                          130939
#                                  ...
# Benkelman                            1
# Old Appleton                         1
# Wildrose                             1
# Mc Nabb                              1
# American Fork-Pleasant Grove         1
# Name: count, Length: 13678, dtype: int64

# %%
cities_by_accident[:20]
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
# Orlando          109733
# Austin            97359
# Raleigh           86079
# Nashville         72930
# Baton Rouge       71588
# Atlanta           68186
# Sacramento        66264
# San Diego         55504
# Phoenix           53974
# Minneapolis       51488
# Richmond          48845
# Oklahoma City     46092
# Jacksonville      42447
# Tucson            39304
# Columbia          38178
# Name: count, dtype: int64

# %%
 df[df['City'] == 'New York']
# Out:
#                 ID   Source  Severity           Start_Time  \
# 194401    A-194408  Source2         2  2016-12-01 08:21:11
# 194415    A-194422  Source2         3  2016-12-01 08:49:35
# 194468    A-194475  Source2         2  2016-12-01 12:08:26
# 194533    A-194540  Source2         2  2016-12-02 05:19:11
# 194551    A-194558  Source3         2  2016-12-02 07:09:04
# ...            ...      ...       ...                  ...
# 7726396  A-7775764  Source1         2  2019-08-20 14:54:26
# 7726942  A-7776310  Source1         2  2019-08-21 17:32:29
# 7727478  A-7776846  Source1         2  2019-08-22 08:16:10
# 7727498  A-7776866  Source1         2  2019-08-22 15:14:32
# 7727997  A-7777365  Source1         2  2019-08-23 10:04:09
#
#                     End_Time  Start_Lat  Start_Lng    End_Lat    End_Lng  \
# 194401   2016-12-01 08:50:48  40.770107 -73.957397        NaN        NaN
# 194415   2016-12-01 09:19:14  40.849579 -73.942314        NaN        NaN
# ...

# %%
type(cities_by_accident)
# Out:
# pandas.core.series.Series

# %%
cities_by_accident[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='City'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set_style("darkgrid")

# %%
sns.histplot(cities_by_accident, log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
# Create the displot with density normalization
sns.displot(cities_by_accident, kde=True, bins=15, color='blue', stat='density')

# Set the title and labels with more descriptive text
plt.title('Density Distribution of Cities with High Accident Rates', fontsize=16)
plt.xlabel('Number of Reported Accidents', fontsize=14)
plt.ylabel('Density', fontsize=14)

# Set y-axis limits and custom ticks
plt.ylim(0, plt.ylim()[1])  # Adjust the upper limit as needed
y_ticks = np.arange(0, plt.ylim()[1], 0.00005)  # Create ticks from 0 to the upper limit with a step of 0.00005
plt.yticks(y_ticks)

# Show the plot
plt.show()

# %%
sns.displot(cities_by_accident, kde=True)  # kde=True overlays a kernel density estimate
plt.xlabel('Cities by Accident')
plt.ylabel('Frequency')  # Change this to your desired label
plt.title('Histogram of Accidents by City')

# Set the y-axis limits


plt.show()

# %%
high_accidents_cities=cities_by_accident[cities_by_accident >= 1000]
low_accidents_cities=cities_by_accident[cities_by_accident <1000]

# %%
len(high_accidents_cities)/len(cities)
# Out:
# 0.08904159660793917

# %%
sns.displot(high_accidents_cities, kind='hist', kde=True,)
plt.show()

# %%
sns.histplot(high_accidents_cities, log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
sns.histplot(low_accidents_cities, log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
cities_by_accident[cities_by_accident == 1]
# Out:
# City
# Lake Andes                      1
# Catoctin                        1
# Duck Hill                       1
# Westbrookville                  1
# Saint Croix                     1
#                                ..
# Benkelman                       1
# Old Appleton                    1
# Wildrose                        1
# Mc Nabb                         1
# American Fork-Pleasant Grove    1
# Name: count, Length: 1023, dtype: int64

# %% [markdown]
# ### Start Time

# %%
df.Start_Time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 7728389    2019-08-23 18:03:25
# 7728390    2019-08-23 19:11:30
# 7728391    2019-08-23 19:00:21
# 7728392    2019-08-23 19:00:21
# 7728393    2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: object

# %%
df.Start_Time[0]
# Out:
# '2016-02-08 05:46:00'

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'], errors='coerce')

# %%
sns.displot(df.Start_Time.dt.hour ,bins=24)
plt.show()

# %%
sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /var/folders/cl/pxlj9h950dbb61br3qlr2djm0000gn/T/ipykernel_67647/362819596.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# - Figure out how to show percentages

# %%
import seaborn as sns
import pandas as pd

# Assuming df is your DataFrame and Start_Time is a datetime column
df['Start_Time'] = pd.to_datetime(df['Start_Time'])  # Ensure it's in datetime format

# Plotting the histogram
sns.histplot(df['Start_Time'].dt.hour, bins=24, kde=False, stat='density')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Density'>

# %% [markdown]
# - A high percentage of accidents occur between 6 am to 10 am (probably people in a hurry to get to work)
# - Next higest percentage is 3 pm to 6 pm.(getting back from work)

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins=7, kde=False, norm_hist=True)
# Out:
# /var/folders/cl/pxlj9h950dbb61br3qlr2djm0000gn/T/ipykernel_67647/308908771.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.dayofweek, bins=7, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# Is the distribution of accidents by hour the same on weekends as on weekdays.

# %%
sundays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 6]
sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /var/folders/cl/pxlj9h950dbb61br3qlr2djm0000gn/T/ipykernel_67647/3630331899.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
monday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 0]
sns.distplot(monday_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /var/folders/cl/pxlj9h950dbb61br3qlr2djm0000gn/T/ipykernel_67647/4268565558.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(monday_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# On Sundays, the peak occurs between 10 am and 3 pm, unlike weekdays

# %%
df_2019 = df[df.Start_Time.dt.year == 2019]
df_2019_Bing = df_2019[df_2019.Source == 'MapQuest']
sns.distplot(df_2019_Bing.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)
# Out:
# /var/folders/cl/pxlj9h950dbb61br3qlr2djm0000gn/T/ipykernel_67647/4159956570.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2019_Bing.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2464: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ...

# %% [markdown]
# Can you explain the month-wise trend of accidents?
#
# - Much data is missing for 2016. Maybe even 2017.
# - There seems to be some issue with the Bing data

# %%
df.Source.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# - Consider excluding Bing data, seems to have issues.

# %% [markdown]
# ### Start Latitude & Longitude

# %%
df.Start_Lat
# Out:
# 0          39.865147
# 1          39.928059
# 2          39.063148
# 3          39.747753
# 4          39.627781
#              ...
# 7728389    34.002480
# 7728390    32.766960
# 7728391    33.775450
# 7728392    33.992460
# 7728393    34.133930
# Name: Start_Lat, Length: 7728394, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 7728389   -117.379360
# 7728390   -117.148060
# 7728391   -117.847790
# 7728392   -118.403020
# 7728393   -117.230920
# Name: Start_Lng, Length: 7728394, dtype: float64

# %%
sample_df = df.sample(int(0.1 * len(df)))

# %%
sns.scatterplot(x=sample_df.Start_Lng, y=sample_df.Start_Lat, size=0.001)
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
import folium

# %%
for index, row in df[['Start_Lat', 'Start_Lng']].sample(100).iterrows():
    print(row['Start_Lat'], row['Start_Lng'])
# Out:
# 35.815151 -78.605591
# 41.579072 -73.05188000000003
# 33.94398 -118.368535
# 41.028188 -111.932555
# 38.19114 -85.72121
# 45.846388 -122.833384
# 33.494949 -112.11705
# 32.282848 -110.969559
# 37.05676 -120.96406
# 37.607217 -122.065011
# 33.875553000000004 -118.193275
# 40.698692 -73.533638
# 35.878651 -78.313538
# 41.3792 -71.904099
# 42.379482 -88.06397199999998
# 45.00968 -93.0719
# 34.12379 -117.20097
# 34.059736 -118.25203
# 35.664272 -78.700559
# 39.881149 -75.00988000000002
# 29.901289 -89.995465
# 31.727259000000004 -106.299767
# 44.63644 -94.043312
# 37.635887 -77.451614
# 32.87529 -96.662859
# 38.422199 -77.421249
# 40.153125 -74.71807700000002
# 32.708134 -96.829781
# 39.537306 -119.783896
# 33.172138000000004 -117.347778
# 45.12092471101226 -93.0495536322925
# 33.664978999999995 -117.883623
# 29.697172 -95.288391
# 33.93450900000001 -78.746338
# 27.983564 -80.554001
# 38.776291 -104.815498
# 39.71041500000001 -111.817696
# 34.250481 -118.865005
# 44.810232 -123.027395
# ...

# %%
zip(list(df.Start_Lat), list(df.Start_Lng))

# %%
from folium.plugins import HeatMap

# %%
sample_df = df.sample(int(0.001 * len(df)))
lat_lon_pairs = list(zip(list(sample_df.Start_Lat), list(sample_df.Start_Lng)))

# %%
map = folium.Map()
HeatMap(lat_lon_pairs).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Ask & answer questions
#
# 1. Are there more accidents in warmer or colder areas?
# 2. Which 5 states have the highest number of accidents? How about per capita?
# 3. Does New York show up in the data? If yes, why is the count lower if this the most populated city.
# 4. Among the top 100 cities in number of accidents, which states do they belong to most frequently.
# 5. What time of the day are accidents most frequent in? - ANSWERED
# 6. Which days of the week have the most accidents?
# 7. Which months have the most accidents?
# 8. What is the trend of accidents year over year (decreasing/increasing?)
# 9. When is accidents per unit of traffic the highest.

# %% [markdown]
# ## Summary and Conclusion
#
#
# Insights:
#
# 1. No data from new york
#
# 2. the number of accidents per city decreases exponentially
#
# 3. less than 9 percent cities have more than 1000 yearly accidents
#
# 4. Over 1000 cities have reported just one accident
